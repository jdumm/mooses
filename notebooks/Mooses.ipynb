# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import math
import cv2

from context import mooses

# %%
import importlib
importlib.reload(mooses)

# Read in example screenshots
filename = "../data/screenshots/Mooses_ex1.png"
frame = cv2.imread(filename) 
frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
frame_result = frame_rgb.copy()

num_moosies = mooses.räkna_älgarna(frame_rgb, frame_result, draw_roi=False)

plt.figure(figsize=(18,12))
plt.imshow(frame_result)
print(f"Älgar över Älven: {num_moosies}")
# Out:
# Älgar över Älven: 0
